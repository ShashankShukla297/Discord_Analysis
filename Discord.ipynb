# %% [markdown]
# # Discord Data Analysis

# %%
import pandas as pd

# %%
# Define chunk size (adjust as needed)
chunk_size = 10000  # Number of rows to read at a time
# Initialize an empty DataFrame to store the concatenated chunks
all_chunks = []
# Create a CSV file iterator
iterator =pd.read_csv('discordoutput.csv',chunksize=chunk_size)
# Iterate through chunks and process each chunk
for chunk in iterator:
    # Process the chunk as needed (e.g., perform calculations, filtering, etc.)
    # For example, you can append it to the list of chunks for further processing
    all_chunks.append(chunk)
# Concatenate all chunks into a single DataFrame
df = pd.concat(all_chunks)
# Now you can work with the entire DataFrame

# %%
df.drop('Unnamed: 0',inplace=True,axis=1)

# %%
df.head()
# Out:
#                                 id user_name  created_at  \
# 0  id:uds:uds::1097755488436887642    VACHAN  1681795703
# 1  id:uds:uds::1079222135001710662      megz  1677377007
# 2  id:uds:uds::1093955826173095990   🖤Umbrå🖤  1680889793
# 3  id:uds:uds::1102786417052102666     Mizyu  1682995170
# 4  id:uds:uds::1092956177933021284  Mooseegg  1680651458
#
#                                        external_link  \
# 0  https://discord.com/channels/99774894902267090...
# 1  https://discord.com/channels/75779462805664572...
# 2  https://discord.com/channels/99774894902267090...
# 3  https://discord.com/channels/99774894902267090...
# 4  https://discord.com/channels/85484326836515642...
#
#                                              content   status  \
# 0                                             Rpg rd  publish
# 1  I was waiting for it to go back down to 1 tick...  publish
# 2                           Is dark better than ice?  publish
# 3                                         a10 to 11?  publish
# 4                   Also known as “Mason Dixon Lime”  publish
#
#                                          user_avatar  is_public  \
# 0  https://cdn.discordapp.com/avatars/10974621971...      False
# 1                                                NaN      False
# 2  https://cdn.discordapp.com/avatars/81824830153...      False
# 3  https://cdn.discordapp.com/avatars/54297301076...      False
# 4  https://cdn.discordapp.com/avatars/32874311128...      False
#
#   source_platform doc_type  ...  \
# 0         Discord     text  ...
# 1         Discord    forum  ...
# 2         Discord     text  ...
# 3         Discord     text  ...
# 4         Discord     text  ...
#
#                                           user_roles  has_attachments  \
# 0                        ['@everyone', '📍warriors📍']            False
# 1                                                NaN            False
# 2  ['@everyone', '📍warriors📍', 'North America', '...            False
# 3  ['@everyone', '_____-----  PING ROLES  -----__...            False
# 4  ['@everyone', 'TDI Updates', 'OG', 'ITG Member...            False
#
#                      created_at_str                   community_name  \
# 0  2023-04-18T05:28:23.754000+00:00                    🍅Fruits Hour🍅
# 1  2023-02-26T02:03:27.962000+00:00                      ✦﹒Sweetener
# 2  2023-04-07T17:49:53.676000+00:00                    🍅Fruits Hour🍅
# 3  2023-05-02 02:39:30.606000+00:00                    🍅Fruits Hour🍅
# 4  2023-04-04T23:37:38.963000+00:00  Independent Traders Guild (ITG)
#
#          community_id parent_doc_id  attachments title thread_id  entities
# 0  997748949022670909           NaN          NaN   NaN       NaN       NaN
# 1  757794628056645722  1.075646e+18          NaN   NaN       NaN       NaN
# 2  997748949022670909           NaN          NaN   NaN       NaN       NaN
# 3  997748949022670909           NaN          NaN   NaN       NaN       NaN
# 4  854843268365156422           NaN          NaN   NaN       NaN       NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Cheaking the Null Values Percentage

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def null_percentage(df):
    # Calculate the total number of rows in the DataFrame
    total_rows = len(df)
    
    # Calculate the percentage of null values for each column
    percentages = (df.isnull().sum() / total_rows) * 100
    
    # Create a new DataFrame to store the results and exclude columns with no null values
    result_df = pd.DataFrame({'Column': df.columns, 'Null Percentage': percentages})
    result_df = result_df[result_df['Null Percentage'] > 0]  # Exclude columns with 0% nulls
    
    if result_df.empty:
        print("No columns with null values found.")
        return result_df
    
    # Sort the DataFrame by Null Percentage in descending order for better visualization
    result_df = result_df.sort_values(by='Null Percentage', ascending=False)
    
    # Create a beautiful bar chart using Seaborn with the 'rocket' color palette
    plt.figure(figsize=(10, 6))
    ax = sns.barplot(x='Null Percentage', y='Column', data=result_df, palette='rocket')
    plt.xlabel('Null Percentage')
    plt.ylabel('Column')
    plt.title('Null Percentage in Each Column')
    
    # Display percentage values on the bars
    for p in ax.patches:
        width = p.get_width()
        ax.annotate(f'{width:.2f}%', (width, p.get_y() + p.get_height()/2), ha='left', va='center', color='black')
    
    plt.show()

    return result_df

# Example usage:
# Assuming you have a DataFrame called 'my_data'
result = null_percentage(df)
result
# Out:
#                               Column  Null Percentage
# attachments              attachments        98.532094
# entities                    entities        96.804633
# thread_id                  thread_id        95.809701
# title                          title        95.809396
# parent_doc_id          parent_doc_id        82.391332
# user_roles                user_roles        33.306995
# user_avatar              user_avatar        17.752318
# content                      content         1.046863
# user_display_name  user_display_name         0.057165
# doc_type                    doc_type         0.054371
# external_link          external_link         0.054371
# channel_name            channel_name         0.054371
# community_name        community_name         0.054371
# user_id                      user_id         0.054218
# user_other_name      user_other_name         0.002795
# user_name                  user_name         0.002795
# channel_id                channel_id         0.000051

# %%
sam=df.sample(1000)

# %%
sam.to_csv('sample.csv',index=False)

# %% [markdown]
# ### Checking for duplicate

# %%
df[df.duplicated('id')]
# Out:
# Empty DataFrame
# Columns: [id, user_name, created_at, external_link, content, status, user_avatar, is_public, source_platform, doc_type, user_other_name, channel_id, user_display_name, user_id, channel_name, user_roles, has_attachments, created_at_str, community_name, community_id, parent_doc_id, attachments, title, thread_id, entities]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['id', 'user_name', 'created_at', 'external_link', 'content', 'status',
#        'user_avatar', 'is_public', 'source_platform', 'doc_type',
#        'user_other_name', 'channel_id', 'user_display_name', 'user_id',
#        'channel_name', 'user_roles', 'has_attachments', 'created_at_str',
#        'community_name', 'community_id', 'parent_doc_id', 'attachments',
#        'title', 'thread_id', 'entities'],
#       dtype='object')

# %% [markdown]
# ### Document ID Validation

# %%
import re

def check_doc_id_format(df):
    # Regular expression pattern for valid document IDs
    regex_pattern = r"id:uds:uds::[A-Za-z0-9]+"

    valid_count = 0
    invalid_count = 0

    # Loop through each document ID in the DataFrame
    for doc_id in df.id:
        # Check if the ID matches the regex pattern
        if re.match(regex_pattern, doc_id):
            valid_count += 1
        else:
            invalid_count += 1

    print("Documents with valid IDs:", valid_count)
    print("Documents with invalid IDs:", invalid_count)

    # Return the counts as a tuple
    return valid_count, invalid_count

# Example usage:
# Assuming you have a DataFrame called 'my_data'
valid_count, invalid_count = check_doc_id_format(df)
# Out:
# Documents with valid IDs: 1967974
# Documents with invalid IDs: 0

# %% [markdown]
# ### Doc_Type Validation

# %%
def validate_doc_types(df, valid_doc_types):
    # Get the set of all values in the doc_type field
    all_doc_types = set(df['doc_type'])

    # Initialize a dictionary to store counts of valid and invalid document types
    counts = {'Valid': 0, 'Invalid': 0}
    
    # Initialize a list to store invalid document types
    invalid_doc_types = []

    # Loop through each document type
    for doc_type in all_doc_types:
        # Check if the document type is a valid string and in the set of valid document types
        if isinstance(doc_type, str) and doc_type in valid_doc_types:
            counts['Valid'] += 1
        else:
            counts['Invalid'] += 1
            invalid_doc_types.append(doc_type)

    # Print the counts
    print("Counts of Document Types:")
    print("------------------------")
    for doc_type, count in counts.items():
        print(f"{doc_type}: {count}")
    
    # Print the list of invalid document types
    if counts['Invalid'] > 0:
        print("\nInvalid Document Types:")
        print("-----------------------")
        for invalid_type in invalid_doc_types:
            print(invalid_type)

# Example usage:
# Assuming you have a DataFrame called 'my_data' and a set of valid document types
valid_document_types =['text', 'forum', 'public_thread', 'news', 'stage_voice','voice']
validate_doc_types(df, valid_document_types)
# Out:
# Counts of Document Types:
# ------------------------
# Valid: 6
# Invalid: 1
#
# Invalid Document Types:
# -----------------------
# nan

# %% [markdown]
# ### Doc_type percentage distribution

# %%
(df.doc_type[~df.doc_type.isnull()].value_counts()/df.doc_type[~df.doc_type.isnull()].shape[0])*100
# Out:
# doc_type
# text             81.920572
# forum            17.802496
# news              0.155066
# voice             0.076262
# public_thread     0.041029
# stage_voice       0.004576
# Name: count, dtype: float64

# %% [markdown]
# ### Calculate null value percentage for each doc_type

# %%
# Calculate null value percentage for each doc_type
null_percentage = df.groupby('doc_type')[['user_name','content','user_avatar','user_roles','parent_doc_id','attachments','title','thread_id','entities']].apply(lambda x: round((x.isnull().sum() / len(x)) * 100, 2))

# %%
null_percentage
# Out:
#                user_name  content  user_avatar  user_roles  parent_doc_id  \
# doc_type
# forum               0.02     3.68        51.48       81.35           8.19
# news                0.00     0.07         0.03       21.51          95.31
# public_thread       0.00     1.73       100.00      100.00           0.99
# stage_voice         0.00     1.11         0.00       10.00         100.00
# text                0.00     0.48        10.44       22.84          98.50
# voice               0.00     0.40         0.00        4.53         100.00
#
#                attachments   title  thread_id  entities
# doc_type
# forum                99.20   81.57      81.57     82.05
# news                 90.16   98.98      98.98    100.00
# public_thread       100.00   98.88      98.88     99.38
# stage_voice         100.00  100.00     100.00    100.00
# text                 98.41   98.89      98.89    100.00
# voice                98.80  100.00     100.00    100.00

# %% [markdown]
# ### Heatmap for the above datapoints

# %%
plt.figure(figsize=(15,8))
plt.title('Null value percentage for each doc_type')
sns.heatmap(null_percentage,annot=True)
plt.show()

# %% [markdown]
# ### Entities Validation

# %%
import pandas as pd
import matplotlib.pyplot as plt

def entities_validation(dataframe):
    # Check if the 'entities' column is present in the DataFrame
    if 'entities' not in dataframe.columns:
        return "The 'entities' column does not exist in the DataFrame."

    # Filter out rows where 'entities' is not null and is an array
    valid_entities_count = 0
    valid_documents_with_entities = 0
    
    try:
        # Convert strings to lists using eval for the 'entities' column
        dataframe['entities'][~dataframe['entities'].isnull()] = dataframe['entities'][~dataframe['entities'].isnull()].apply(lambda x: eval(x))
        for entities_list in dataframe['entities']:
            if isinstance(entities_list, list):
                valid_entities_count += 1
                if len(entities_list) > 1:
                    valid_documents_with_entities += 1

        total_documents = len(dataframe)

        # Calculate percentages
        valid_entities_percentage = (valid_entities_count / total_documents) * 100
        valid_documents_with_entities_percentage = (valid_documents_with_entities / total_documents) * 100
        documents_without_entities_percentage = 100 - valid_documents_with_entities_percentage

        # Create a bar chart to visualize the validation results
        plt.figure(figsize=(10, 6))
        validation_results = {
            "Valid Entities Count": valid_entities_percentage,
            "Documents with at least 2 Entity": valid_documents_with_entities_percentage,
            "Documents without any Entities": documents_without_entities_percentage
        }
        plt.bar(validation_results.keys(), validation_results.values(), color='skyblue')
        plt.xlabel('Validation Metrics')
        plt.ylabel('Percentage')
        plt.title('Entities Validation Results')
        plt.ylim(0, 100)  # Set the y-axis range to 0-100 for percentages
        plt.show()

        return {
            "Total Documents": total_documents,
            "Valid Entities Percentage": round(valid_entities_percentage,2),
            "Documents with at least 2 Entity Percentage": round(valid_documents_with_entities_percentage,2),
            "Documents without any Entities Percentage": round(documents_without_entities_percentage,2)
        }
    
    except:
        
        for entities_list in dataframe['entities']:
            if isinstance(entities_list, list):
                valid_entities_count += 1
                if len(entities_list) > 1:
                    valid_documents_with_entities += 1

        total_documents = len(dataframe)

        # Calculate percentages
        valid_entities_percentage = (valid_entities_count / total_documents) * 100
        valid_documents_with_entities_percentage = (valid_documents_with_entities / total_documents) * 100
        documents_without_entities_percentage = 100 - valid_documents_with_entities_percentage

        # Create a bar chart to visualize the validation results
        plt.figure(figsize=(10, 6))
        validation_results = {
            "Valid Entities Count": valid_entities_percentage,
            "Documents with at least 2 Entity": valid_documents_with_entities_percentage,
            "Documents without any Entities": documents_without_entities_percentage
        }
        plt.bar(validation_results.keys(), validation_results.values(), color='skyblue')
        plt.xlabel('Validation Metrics')
        plt.ylabel('Percentage')
        plt.title('Entities Validation Results')
        plt.ylim(0, 100)  # Set the y-axis range to 0-100 for percentages
        plt.show()

        return {
            "Total Documents": total_documents,
            "Valid Entities Percentage": round(valid_entities_percentage,2),
            "Documents with at least 2 Entity Percentage": round(valid_documents_with_entities_percentage,2),
            "Documents without any Entities Percentage": round(documents_without_entities_percentage,2)
        }

# Example usage:
# Assuming you have a DataFrame called 'my_data'
result = entities_validation(df)
result
# Out:
# C:\Users\shukl\AppData\Local\Temp\ipykernel_4588\2230716256.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['entities'][~dataframe['entities'].isnull()] = dataframe['entities'][~dataframe['entities'].isnull()].apply(lambda x: eval(x))
# {'Total Documents': 1967974,
#  'Valid Entities Percentage': 3.2,
#  'Documents with at least 2 Entity Percentage': 2.13,
#  'Documents without any Entities Percentage': 97.87}

# %% [markdown]
# ### Source Platform Validation

# %%
import pandas as pd

def source_platform_validation(dataframe, valid_platforms):
    # Check if the 'source_platform' column is present in the DataFrame
    if 'source_platform' not in dataframe.columns:
        return "The 'source_platform' column does not exist in the DataFrame."

    # Filter out rows where 'source_platform' is not null
    valid_platform_count = 0
    invalid_platform_count = 0
    invalid_platforms = []

    for platform in dataframe['source_platform']:
        if isinstance(platform, str) and platform in valid_platforms:
            valid_platform_count += 1
        else:
            invalid_platform_count += 1
            invalid_platforms.append(platform)

    total_documents = len(dataframe)

    return {
        "Total Documents": total_documents,
        "Valid Platform Count": valid_platform_count,
        "Invalid Platform Count": invalid_platform_count,
        "Invalid Platforms": invalid_platforms
    }

# Example usage:
# Assuming you have a DataFrame called 'my_data' and a list of valid platforms
valid_platforms = ["Discord"]
result = source_platform_validation(df, valid_platforms)
result
# Out:
# {'Total Documents': 1967974,
#  'Valid Platform Count': 1967974,
#  'Invalid Platform Count': 0,
#  'Invalid Platforms': []}

# %% [markdown]
# ### Validate Dates And Timestamps

# %%
import pandas as pd
from datetime import datetime

def validate_dates_and_timestamps(dataframe):
    # Check if the 'created_at' and 'created_at_str' columns are present in the DataFrame
    if 'created_at' not in dataframe.columns or 'created_at_str' not in dataframe.columns:
        return "The required columns 'created_at' and 'created_at_str' do not exist in the DataFrame."

    # Convert 'created_at' to datetime and handle invalid values with 'coerce'
    dates = pd.to_datetime(dataframe['created_at'], errors='coerce', unit='s')

    current_datetime = datetime.now()

    valid_dates = 0
    invalid_dates = 0

    for date in dates:
        if date < current_datetime:
            valid_dates += 1
        else:
            invalid_dates += 1

    v_d = 0
    iv_d = 0

    for created_at, created_at_str in zip(dates, dataframe['created_at_str']):
        x = str(created_at)[:10]
        y = str(created_at_str)[:10]
        if x == y:
            v_d += 1
        else:
            iv_d += 1

    total_documents = len(dataframe)

    return {
        "Total Documents": total_documents,
        "Valid Dates Count": valid_dates,
        "Invalid Dates Count": invalid_dates,
        "Valid Timestamp Count": v_d,
        "Invalid Timestamp Count": iv_d
    }

# Example usage:
# Assuming you have a DataFrame called 'my_data'
result = validate_dates_and_timestamps(df)
result
# Out:
# {'Total Documents': 1967974,
#  'Valid Dates Count': 1967974,
#  'Invalid Dates Count': 0,
#  'Valid Timestamp Count': 1967974,
#  'Invalid Timestamp Count': 0}

# %% [markdown]
# ### is_public Validation

# %%
import pandas as pd

def is_public_validation(dataframe):
    # Check if the 'is_public' column is present in the DataFrame
    if 'is_public' not in dataframe.columns:
        return "The 'is_public' column does not exist in the DataFrame."

    valid_count = 0
    invalid_count = 0
    true=0
    false=0

    for is_public in dataframe['is_public']:
        if isinstance(is_public, bool):
            valid_count += 1
            if is_public:
                true+=1
            else:
                false+=1
        else:
            invalid_count += 1

    total_documents = len(dataframe)

    return {
        "Total Documents": total_documents,
        "Valid is_public Count": valid_count,
        "Invalid is_public Count": invalid_count,
        "True":true,
        "False":false
    }

# Example usage:
# Assuming you have a DataFrame called 'my_data'
result = is_public_validation(df)
result
# Out:
# {'Total Documents': 1967974,
#  'Valid is_public Count': 1967974,
#  'Invalid is_public Count': 0,
#  'True': 626,
#  'False': 1967348}

# %%
# Filter the DataFrame to select rows where 'is_public' is True, then group by 'doc_type' and count the occurrences.
(df[df.is_public].groupby('doc_type')[['is_public']].count()/df[df.is_public].shape[0])*100
# Out:
#           is_public
# doc_type
# forum      1.277955
# news       0.479233
# text      98.242812

# %%
# Filter the DataFrame to select rows where 'is_public' is False
# Group the filtered DataFrame by 'doc_type' and count the occurrences of 'is_public'
(df[~df.is_public].groupby('doc_type')[['is_public']].count()/df[~df.is_public].shape[0])*100
# Out:
#                is_public
# doc_type
# forum          17.798071
# news            0.154879
# public_thread   0.041020
# stage_voice     0.004575
# text           81.870823
# voice           0.076245

# %% [markdown]
# ### Title Case Validation

# %%
import pandas as pd

def title_case_check(dataframe, column_name):
    # Check if the specified column is present in the DataFrame
    if column_name not in dataframe.columns:
        return f"The '{column_name}' column does not exist in the DataFrame."

    valid_count = 0
    invalid_count = 0
    invalid_titles = []

    for title in dataframe[column_name]:
        if isinstance(title, str) and title[0].isupper():
            valid_count += 1
        else:
            invalid_count += 1
            invalid_titles.append(title)

    total_documents = len(dataframe)

    # Calculate percentages
    valid_titles_percentage = (valid_count / total_documents) * 100
    invalid_titles_percentage = (invalid_count / total_documents) * 100

    return {
        "Total Documents": total_documents,
        "Valid Titles Count": valid_count,
        "Valid Titles Percentage": round(valid_titles_percentage,2),
        "Invalid Titles Count": invalid_count,
        "Invalid Titles Percentage": round(invalid_titles_percentage,2),
        "Invalid Titles": set((invalid_titles))
    }

# Example usage:
# Assuming you have a DataFrame called 'my_data' and the column name is 'title'
result = title_case_check(df, 'title')
result
# Out:
# {'Total Documents': 1967974,
#  'Valid Titles Count': 48677,
#  'Valid Titles Percentage': 2.47,
#  'Invalid Titles Count': 1919297,
#  'Invalid Titles Percentage': 97.53,
#  'Invalid Titles': {'trading perm buddha for Perm Dough',
#   'sent your offer',
#   'trading 2x money or mastery or fruit storage and boss drops',
#   'trade perm Buddha',
#   'trading spirit for dragon or mochi',
#   'i need perm portal',
#   'my control for shadow buddha',
#   'trading any gamepass',
#   'trading dark blade gamepass hmu nd offer',
#   'trading spider, quake, gravity, and paw',
#   'gravity dragon paw string and magma for somthin',
#   'shadow',
#   'venom blizzard and portal for trade',
#   'trading spirit for buddha and rumble',
#   'trading paw for portal',
#   '1%er',
#   'trading spirit and love for dragon or dough',
#   'trading 2 bliz 2 buddha',
#   '3x shadow and portal for 2x mastery',
#   'dough for dragon and adds',
#   'trading dragon spirit and gravity!!!',
#   'dragon and dough for leopard?',
#   'trading string and 3 more',
#   'trading string for a trade up seris',
#   'trading anything u have to buy',
#   'trading fast boats looking for venom or dragon',
#   'trading fruit stirage',
#   '2 dough 1 Leo 1 Buddha for permanent buddha',
#   'trading acc',
#   'leopard forr gamepass or dark blade',
#   'trading string quake and magma for 2x boss drops',
#   'tradeing this fruits',
#   'trading dough i want 2x mas',
#   'trading all my fruits and 2 gamepasses for perm leo',
#   'trading: (dragon x2) (venom x1) (shadow x3) (gravity x2) (rumble x2) (portal x2) (phoenix x2)',
#   'dough nd adds for fast boat',
#   'trading dough and shadow for 2x mastery dm me if u have',
#   'looking for dragon and buddha and like a pheoinx as an add',
#   'my services for robox items',
#   'spider love and paw for buddha',
#   'tradeo dragon, venom and shadow',
#   'trading: Leopard, Shadow and Blizzard!!! dm if you wanna offer',
#   'trading venom and shadow fruit',
#   'gravity quake for rumble',
#   'trading venom mlf shadow rumble and a good add',
#   'looking for 2x drop',
#   'who has love fruit',
#   'looking for perm magma',
#   'trading Phoenix and gravity',
#   '2 doughs love and spider for leopard',
#   'can someone carry and host 2 dough raids I’ll give pheonix and 3/3 bounty',
#   '2x max 2x money fast boats boss drop any of. those gp just give me a good offer',
#   'looking perm fruit',
#   'zzzzz',
#   'trade venom and grav for dragon',
#   'trading dough for spirit and venom',
#   'trading leopard venom 2 control Buddha shadow 2 rumble 2 portal and 2 string',
#   'trading spider and love for portal',
#   'tading venom buddha control rumble',
#   'trade papa please',
#   'trading these any offers?',
#   'looking for perm rubber',
#   '4⃣🐆👉🍎🧭4⃣🐆👉🍎🧭4⃣🐆👉🍎🧭',
#   'robux',
#   'trading any gamepass under 500 robux in blox fruit for dragon and dough',
#   'dough for mirage and fullmoon',
#   'trading spirit and shadow and paw and spider and love dm me if u want',
#   'lf gamepass or dragon',
#   'traiding my SPIRT CONTROL SHADOW AND BLIZZARD AND MORE',
#   'trading Shadow Blizzard Portal for +1 storage',
#   'rubber for magma',
#   'trading dragon spirit and portal',
#   'traiding shadow and spirit',
#   '3 dragons and 1 control and a huge add for permanent portal or perm dough or perm dm',
#   'trading one game pass',
#   'anyone got fruit notifier',
#   'trading Venom and budha',
#   'trading some free fruits dm me',
#   'trade controll',
#   'venom for control shadow and buddha',
#   ':u',
#   'trading for gamepass',
#   'who has pheonix',
#   'trade dragon for x2 money',
#   'trading 2 doughs and spirit dm me if u have offer',
#   'trading dough,portal,and 2 phoniex for perm ice',
#   '2x mastery trade',
#   ':blizzard: 👉🏻❓',
#   'trading dough dragon and venom for leopard',
#   'trading fruits for adopt me legendarys',
#   'piloting advance raids just dm me (full awake costs me leo or fruit storage)',
#   'trading dough,pheonix and magma and quake in king legacy for offers',
#   'i want people to join my private server in arsenal',
#   'looking for leo plus add',
#   'trading spirit + phoenix',
#   'trading string magma and light for phoenix',
#   'trading portal and gravity',
#   'me when big fards',
#   'phoenix+love your offer',
#   '#trading dough and a lot of more lk for dragon Plus affä',
#   'for spirit',
#   'two doughs venom and portal for leapord',
#   '★ Talon Knife★ Survival Knife | Fade FN★ Ursus Knife | Marble Fade FN★ Talon Knife | Blue Steel M',
#   'who have dragon or control',
#   'trading any go for dough',
#   'trading dragon and blizzard',
#   'looking for huges psx (NGF)',
#   'trading leopard LF 2 doughs dragon and venom',
#   'i have control 2dough buddha and portal(and adds like quake love spider) for trade',
#   'trading gamepasses under 1k robux',
#   'ı\'m making a "kilo to leopar" series',
#   'lf perm buddha ( dm )',
#   'trading portal, string and spirit',
#   'trading Buddha + whatever for dough',
#   'looking to get venom offering rumble and Buddha.',
#   'wtb perm magma',
#   'looking for cheap leo or dough for drag',
#   'trading leopard for a decent perm or gamepass',
#   'trading 2 Leopards',
#   ':fcontrol4: :point_trade: dm: if u want to offer',
#   'anyone trading max gpo acount? dm me',
#   'trading perm buddah for two leos and two spirits',
#   'dough dragon and venom',
#   'looking for magma im trading  quake',
#   'my dough for ur 2x boss',
#   'who has dark blade/Yoru',
#   'trading light magma Barrier and rubber',
#   '2 sprits and dragon',
#   'trading control + paw!',
#   'grav',
#   'trading go for dough or Leo',
#   'selling max acc',
#   'who have permament dragon my offer 5 leopard',
#   'trading dough and blizzard for leopard',
#   'trading control, rumble, paw, and pheonix',
#   'i have 4 Leopard 4 Blizzard 2 spirit',
#   'lf perm 🐆',
#   'trading anything below 1300 rbx',
#   'trading my inv and yes I have 2 shadows',
#   'trading shadow pheonix love and portal',
#   'trading blizzard for gamepass',
#   'trading dough shadow gravity paw love and quake',
#   'trading leo 2x dragon and 1 control +other',
#   'trading dough gravity nd shadow etc',
#   'trading 4 dragons for fruit notifier',
#   'portal and love for buddha',
#   'i can t see you private server Ripツ 3054',
#   'trading dragon spirit venom Buddha for gamepasses',
#   'trade dragon bliz portal',
#   'trading string for phoenix',
#   'trading phoenix gravity rumble portal for dough plz',
#   'portal control and paw',
#   'what gamepass would i get for this fruits?',
#   'trading Dough ect..',
#   'trading magma, quake, barrier, dark, flame and ice',
#   'trading love dragon spirit phoenix and dough',
#   'tradings furit',
#   'trading love and light for Phoenix',
#   'looking for any gamepass stored or perm fruits',
#   'looking for fast boat pls',
#   'who have dough?',
#   'uwho have good perm fruit',
#   'trading for a fruit notifier',
#   'trading gravity rumble string and love for offers',
#   'trading 1+ fruit storage and fast boats',
#   'leopard for pet sim x pets and gems',
#   'trading love fruit 💗',
#   'trading dragon for dough Buddha',
#   'looking for something Ok',
#   'trading grav blizzard pheonix',
#   'trading perm kilo( just offer idk why kilo but still have a value😃)',
#   'looking for leopard',
#   'trading leopard and control',
#   'trading Leo, 2x venoms , dragon, dough, shadow',
#   'trading control shadow and portal',
#   'trading +1 fruit capcity for dough+buddha',
#   'trading 3 leopards for rumble perm',
#   'spirit control looking for upgrade',
#   'trading venom control and dough',
#   'trading dough want good offers',
#   'trading venom dragon dough buddha',
#   '2X DOUGH & 2X LEO FOR PERM DOUGH',
#   'trading 110 leo',
#   'trading all this for huges in psx or rumble or just good offers',
#   'for trade 3 dragon',
#   'trading 2 fruit storages',
#   'trading spirit for venom and 2 love',
#   'trading for good offers',
#   'trading perm under 800 robux for pet sim huge atleast 2 or 3 no hell rock',
#   'trading venom+adds',
#   'trading LF gamepasses or offer',
#   'give perm budha for 3 raids dough Carry',
#   'who can help with trials?',
#   'trading paw, magma and light for dough',
#   'tad',
#   'trading all my fruits for game passes',
#   'trading Portal+Quake+Barrier+Light For Buddha',
#   'trading 2 blizzards portal and shadow',
#   'trading 2 Blizzards for 2 spirits',
#   'trading spirit gravity rumble spider Phoenix and love',
#   'trading spieder portal and quake for perm portal',
#   'have Leo',
#   'trading paw pheonix and string for shadow',
#   'trading any gamepass under 500 robux for dough dm me',
#   'looking for 2 fruit storage',
#   'k',
#   'trading gravity control portal and rumble',
#   'trading Dough Leopard venom spirit',
#   'trading darkblade for good exclusive or huge in pet sim x ngf (I also bloxfruit)',
#   'trading two leos , dough,spirt,vemon,shadow, blizzard for perm leo',
#   'need 2x mastery dm if have',
#   'game pass for trade',
#   'trading dragon venom love phoenix and control',
#   'can someone offer',
#   'trading suff',
#   'who had dark blade',
#   'lf good upgrade.',
#   'trading shadow for buddha n adds',
#   'looking for...',
#   'trading portal looking for buddha',
#   'trading shadow gravity and dragon',
#   'trading dark blade',
#   'trading quake, spider and light',
#   'trading dough and adds lf +1 fruit storage or other things',
#   'frag farm',
#   'trading portal and paw dm me for offers',
#   'offer budha',
#   'trading for anything',
#   'trading 2 leos,dough and shadoe',
#   'trading Spider Barrier and rubber...',
#   'trading perm magma looking for 4 leos or 3 leos and a add',
#   ':spirit: :venom: :point_trade: :storage:',
#   'hello',
#   'giving a account with dough one fruit Battleground for +1 fruit storage or other things.',
#   'dough blizzard and portal for storage',
#   'lf for exclusive or huge',
#   'hello_bye_idk0',
#   'trading control+venom+phoenix',
#   'trading leopard for 2x dough and adds',
#   'trading for perm portal or good offer',
#   'tips for trading??',
#   'i need a fist of darkness for cyborg race',
#   'trading leo and dragon for x2drop and fruit storage',
#   'ahh',
#   'trading 2 leopard and 1 spider and rumble for perm phoenix',
#   'trading Leo insta accept 2 drags 1 dough or 2 drags 2 controls',
#   'trading string magma',
#   'trading 2 perm kilo’s and 1 fruit storage',
#   'dm if legendary sword dealer in your server',
#   'trading 2 buddha and 2 portal for dough',
#   'trading venom rumble spider and quake for dough',
#   'trading Dragon,blizzard,Spirit venom and buddha',
#   'trading paw 2x spider',
#   'trding 2 dragons and a portal',
#   'trading leopards and adds',
#   'trading Perm buddha, perm magma, perm quake and fruit storages',
#   'trading spirit gravity Phoenix and rumble',
#   'venom spirit and buddha :point_right: offers',
#   'offerrr',
#   'quadruggy',
#   'trading this and also quake',
#   'blizzard for dough',
#   'only looking for perms',
#   'trading dough shadow portal phoenix',
#   'looking for fast boats or 2x mastery stored',
#   'trading leo, 2 doughs, 2 dragons, and venom',
#   'trading dragon spirit and buddha',
#   'looking for Budha) will trade spider quake barrier and rubber',
#   'trading venom shadow spirit Buddha',
#   'shadow for control',
#   'lloking for 2x mastery',
#   'trading blizzard for control',
#   'pls offer',
#   'trading 1+ for leopard',
#   'trading FRUITS FOR PERMANENT FRUIT ONLY',
#   'trading blizzard venom and spirit',
#   '3 dragons and 1 control and a huge add for permanent portal or perm dough or good perm',
#   'urus knife test',
#   'trading blizzard for buddha and extra fruit',
#   'trading for perms',
#   'trading: Control,venom,blizzard,portal,spider,quake',
#   'dm me if u have 2x mastery',
#   '1 leo for 2 dragons',
#   ':spirit: :point_right: :Buddha: :Buddha: :Buddha: :arrows_counterclockwise: :question:',
#   'tradeing 2 magmas 1 love and 1 light',
#   "hi '",
#   'trading plus one storage for dough and control and portal add like buddha Aswell',
#   'trading my portal that nobody wants',
#   'trading gravity and spider',
#   'trading dough gravity paw spirit phoenix spider quake and portal',
#   'trading dough for drag and spirit',
#   'trading control and gravity for venom',
#   'looking  for portal i offer phoenix and quake if you dont want the phoenix or quake i have gravity',
#   'tradeing all',
#   'trading dough for fast boats or any gp',
#   'trading 4 dough for perm fruit (no common perm)',
#   'bleh',
#   'trading +storage',
#   'trading dough and control for 2x money or fruit storage maybe 2x mastery',
#   'trading Leo for x2 money and fast boats or a perm',
#   'can anyone trade something for Magma and Rubber?',
#   'trading triple dark blade',
#   '#trading control',
#   'hosting dough for fruit',
#   '3 Dragons LF OFFERS',
#   'trading 2x mastery and Dragon',
#   'trading dragon and control for bilerd an adds',
#   'trading a shadow,grav,and Phoenix or love for something',
#   'trading leopard',
#   'trading mid dough fruit',
#   '2x spirit for dragon',
#   'trading dough for dragon and 2 control',
#   'trading my dragon for spirit and buddha rush',
#   '1 storage capacity',
#   'my leo for dough dragon spirit and Buddha',
#   'trading blox fruits',
#   'i m doing a challenge from kilo to leopard now i have barrier and rubber can someone help me',
#   'lf for leopard',
#   'trading spirit and pheonix for 2x drop',
#   'trading blizzard rumble paw spider buddha quake',
#   'any offers for 2x mastery and bomb perm',
#   'trading 2x mastery for leo add',
#   '?????',
#   'trading leo for game passes or good offers',
#   'spawning katakuri in exchange of a fruit',
#   'i trade permanent fruits ice IS the BEST. and any gamepass for dragón',
#   'trading 1 leo, dough, dragon, venom, buddha 3 blizzards',
#   'trading rumble and phoenix for shadow',
#   'nigrs',
#   'trading Perma leo',
#   'trading good stuff',
#   'trading god chalice for dimension summon for a fruit',
#   'trading Buddha love quake control',
#   'control buddha gravity spider and love',
#   'trading spirit, phoenix and portal for dough',
#   'trading love spider and quake',
#   'trading for something',
#   'v4',
#   'trade leopoard',
#   '😡 Rat Bullying & Rat Love 🥰',
#   '3 venom 3 portal shadow buddha phoenix',
#   'trading rumble gravity portal and love for dough and 3/3 if u want',
#   'love and phenoex for 8b gems in pet sim',
#   'trading portal and love for rumble',
#   'trading 2 leo 2 dough',
#   'pls dragon',
#   'trading Buddha and gravity for dough',
#   'trading leopard and rumble for venom and buddha negotiable',
#   'trading perm kilo best perm',
#   'trading Phoenix and magma',
#   'lf mochi, giving buddha (can add)',
#   'i only can store 2 fruits',
#   'trading blizzard and 2 Buddha and portal for a perm or leo',
#   'sry for double ping',
#   'tradeing control',
#   'trading contol and buddha and quake',
#   '2x buddha',
#   'trading spirit and rumble for dragon',
#   'trading any game pass besides money storage or dark blade',
#   'giving dragon and buddha for fruit storage',
#   'trade 4 leopards dor 1 permanent dough',
#   'trading dragon and buddha for storage',
#   'grinding for you💜',
#   'trading very good adopte me pets ( frost fury FR, kangouroo FR, ninja monkey FR, and others fly ride',
#   'trading 3 drag 3 spirit 2 venom for good offer',
#   'guys i want perm (1+m fruits (',
#   'buddha offer',
#   'tradin 10 leopards 5 doughs and I’ll giveaway 1 free venom to whoever comments last by 8:30',
#   'trading x2xp x2money luxury boats and 1 more storage',
#   'trading 2dough 2shadow for permanent fruits Dm me',
#   '#trading dough',
#   'tradin x2 mastery and x2 drop rates',
#   '#Drew’s Shop',
#   'trading this feel free to offer',
#   'trading dough for double money',
#   'trading leopard and venom',
#   'control and love for dough',
#   'trading my fruits2 dough 2 dragon2 Buddha1 blizzard DM for offersNlf op Ignore=nty or clown',
#   'fruit storage for Leopard',
#   'w/l portal barrier kilo for string and phoenix',
#   'trading 2 buddhas spider  dragon control and good adds',
#   'closed - trade completed',
#   'trading portal for 3 magmas or 2 magmas and a light',
#   'trading phoenix quake light rubber',
#   'trading rubber and flame',
#   'trading shadow buddha and venom',
#   'spawning dough king dm if interested',
#   'lf perm control or perm venom',
#   'trading spirit and portal for venom or dragon',
#   'does anyone here have 450+ robux',
#   '1 dough 1 spirit 1 venom for leo',
#   'trading 2 controls and 2 drags',
#   'for dragon',
#   'trading dragon portal and phoenix',
#   'my shadow for pheonix and buddha',
#   'self-directed ETFs',
#   'winter sky dealer blox fruits',
#   'i offer for Leopard',
#   'gimme offer',
#   'trading dragon phoenix for venom rumble or venom and buhhda',
#   'lf for good offer',
#   'gravity and love',
#   'rumble and gravity for shadow',
#   '2x money',
#   'trading dragon plus spirit',
#   'trading love + adds of your choice for spider',
#   'trading these, LF offer, MLF dough',
#   'trading 2 dragons for dough',
#   'dragon control shadow and string for 2× mastery',
#   'trade dragon blizza and shadow for +1 storage',
#   'trading dragon fast boats and 2 buddhas',
#   'trading 2x mastery LF good offer😁',
#   'trades !',
#   'trading magma for offers',
#   'trading portal and buddha for dough or blizzard',
#   'trade please',
#   'trading control (control is coming rework)',
#   'trading dough and paw for leo?',
#   'giving shadow for buddha and quake',
#   'trading phoenix portal and love for something decent',
#   'trading rumble, quake, and venom',
#   'traiding my inventory',
#   'i tread shadow bodha',
#   'trading dragon and buddha for x2 money',
#   'trading perm ice and chop',
#   'frick casey and probot',
#   'trading any gamepass under 1000',
#   'trading dough !!',
#   'good offer ?',
#   'trading dough put all the offer you got',
#   'looking for buddha and dough',
#   'trading phoenix dm for offer',
#   'trading my adopt me pets for Blox fruits',
#   'trading spirit for 2 buddha',
#   'dragon shadow and rumble + magma',
#   'trading control shadow portal and spider for dough',
#   'trading dragon and soul',
#   '4 Leos or 4 dragons for perm portal or phoenix perm',
#   'trading 2 shadows for dragon',
#   '4 Leo for?',
#   'trading control',
#   'trading my fruits for Psx pets or gems',
#   'i need perm buddha',
#   'trading spider quake and love',
#   'trading paw and string for rumble',
#   'trading buddha and 2 portals',
#   'trading 4x dough',
#   'trading dough, grav, control for offer..',
#   'trading douch',
#   'trading 1+ storage',
#   'for gamepasses',
#   'shadow paw 2 spiders for dough',
#   'trade my control',
#   'trading paw and blizzard dm for offer',
#   'trading dough and adds for dark bladd',
#   'trading leo for fruit storage and 1 dough',
#   'dough+rumble=?',
#   'trading spirit dragon shadow and gravity for fruit storage or offers',
#   'trading leo for 2 dragon',
#   'trading Dragon Control',
#   'treading leo for two dragons and control',
#   'im trading fast boat/xs boss drops offer now',
#   'lf love',
#   '2 doughs + add for your Leo',
#   'trading shadow and love',
#   'mSafe',
#   'trading 400 robux gamepass',
#   'dm',
#   'trading 2 leo 3 dragon 3 spirit and other mythicals',
#   'paying string if you can help me kill a seabeast',
#   'trading dragon and venom',
#   'trading String and Quake',
#   'rumble paw magma and rubber and portal for dough',
#   'giving leopard for 2 doughs and an add (shadow/buddha/rumble/blizzard)',
#   'looking for dough and trading 3 perm kilos',
#   'doing anything for perm fruit',
#   'trading magma for any fruit c:',
#   'trading dragon+buddha for 2x mast',
#   'trading Buddha portal and shadow',
#   'trading 800 robux',
#   'trading spirit & venom & phoenix',
#   'trade dought Phoenix quake and rubber for 2x money',
#   'trading spirit and venom for dragon or dough',
#   '2 Leapords 2 Doughs',
#   '4 leopards and more',
#   'tthread 2',
#   'i need Fast boats or +1 fruit storage  or perm fruits',
#   'looking for w trades',
#   'what?',
#   'trading dough for 2x money or 2x boss drop or fruit storage',
#   'trading buddha, and Dough',
#   'no image',
#   'trading 2x boss drops or fast boats',
#   'trading leo for 2 dragons',
#   'trading dragon spirit',
#   'offers for perm spin?',
#   'trading spirit venom good offers only no grav or control',
#   'trading leopard (no don’t ping me about dragon)',
#   'trading dough venom and shadow',
#   'trading perm kilo and perm spin',
#   'trade paw and pheonix for blizzard and some bad adds for value diff',
#   'trading venom lf dough maybe',
#   'tradeing leopard',
#   'looking for 3x dragon fruit im offering some good stuff',
#   'trading leo for dragon + dough + venom',
#   'trading control shadow phoenix and string',
#   'trading fruit storage for dough and adds',
#   'trading leo for perm buddha',
#   'trading perm human buddha',
#   'trading buddha, love, light and magma',
#   'trading dragon for dough',
#   'trading 4x love',
#   'trading leopard shadow 2 spirits venom',
#   'trading blizzard gravity for buddha',
#   'trading 5 leo 1 dough 1 rumble 1 spider',
#   'trading 2x mstery and stat refund',
#   'trading 1 leopard 1 dough 2 venoms 1 buddha 1 love and 2 quakes for perm dough , also taking offers',
#   'trading my dough blizzard and 2 buddah for good offer',
#   'trading spirit for venom and a good add',
#   'trading venom, quake, rubber, and magma for dragon',
#   'trading Buddha and control for dough',
#   'trading 1 leo 1 dragon 1 spirit 2 portal 3 pheonix 3 string 3 quake',
#   'tarde',
#   'trading leopard for pet sim x stuff',
#   '1 leo for 2 dough',
#   'trading dough and add for 2x mastery',
#   'trading rumble for 3 magmas',
#   'trading paw rumble love and buddha',
#   'string and quake for anything good',
#   'offering for perm dough',
#   'trading dough for boats',
#   'trading 2 leopard and dragon and spirit for portal perm',
#   'trading 9 dragons and 8 controls',
#   'lf 2x money or buddha',
#   'shadow blizzard phoenix love lf venom or control',
#   'lf perm fruits',
#   'trading gravity and Buddha',
#   'trading 2 buddah 2 leo 2 control and venom and shadow',
#   'trading shadow pheonix magma im looking for venom or goood offer',
#   'trading dark blade, venom and buddha',
#   'trading quake and dark Ofer want string',
#   'trading dragon string and paw',
#   'phoenix',
#   'trading dough quake and paw for dragon',
#   'trading dragon and spirit lf Leo',
#   'trading these',
#   'i need X2 Money',
#   '2 Leo for 2x mas and 2x money',
#   'trading triple darkblade',
#   '😝DOUGH😝',
#   'looking for very cheap ase',
#   'trading shadow for venom',
#   '2x mastery for fruit',
#   'free things',
#   'trading phoenix and rubber for portal',
#   'gravity and rumble',
#   'i want x2 mastery and x2 money for leopard and buddha',
#   'im looking for perm buddha',
#   'trading dragon spirt 2 control 2 blizzard rumble shadow phoenix 2 love 2 string and 2 quake',
#   'trading dragon  2 phoenix and spider',
#   'trading perms and gamepasses',
#   'who have good perm fruit?',
#   'trading Leopard for perm Buddha',
#   ':lookingfor: 2⃣❎🇩 🇷 🇴 🇵 and good perm fruits',
#   'trading thees fruits',
#   'trading bloc fruit acc',
#   'trading buddha and shadow',
#   'trade my fruits',
#   'trading control buddha shadow and portal',
#   '????',
#   'lf perm dragon',
#   'trading these (I have 1 drag btw)',
#   'troco control e gravidade',
#   'lf 2dragon I have good offer',
#   'trade 2 Leo 2 dragon/ spirit / venom',
#   'trading Buddha Paw Spider and Love',
#   'trading leopard - looking for +2 fruit storage',
#   'trading 2 loves, Dragon, Spirit, Control, Venom, Gravity, Paw and Phoenix',
#   'have dragon looking for +1 storage',
#   'trading portal DM ME',
#   '2 doughs for Leopard',
#   'trading venom rumble portal and buddha',
#   'traiding leopard for Fast boat and +1 fruit storage',
#   'trading dragon control and dough',
#   'trading blizzard fruit portal string and quake .DM me',
#   'looking for leopord',
#   'trading quake and string for phoenix',
#   'trading perm magma',
#   'control, shadow, paw, string im trading',
#   'trading paw for string',
#   'trading every fruit in the game',
#   'trading 2x boss drop offer pls',
#   'trading dough and gravity',
#   'trading leo for fruit storage +adds',
#   'hosting any raid except dough for fruits',
#   'trading perm buddha, and fruit notifier',
#   'reply if you have gamepasses to trade, and I will offer',
#   'control quake',
#   'trading 2 dragon',
#   'trading x2 mastery  x2 drop venom shadow portal and Buddha',
#   'pheonix for control or rumble, Love for anything',
#   'trading 3 buddha',
#   'trading 4 leos for perm dragon dm me if u got it',
#   'trading dragon, venom and spirit for leopard',
#   'trading really what perms',
#   'dough for +1 slot bag',
#   'trading leopard dough venomm buddha for perm fruit',
#   'bhudda',
#   'giving spirit for maraige and full moon looking for gear',
#   'trading dough for dragon and smt under rumbel and above buddha',
#   'have dragon want offers',
#   'trading control and buddha for fast boat',
#   'anyone have dark blade',
#   'trading buddha and venom send dm',
#   "lf perms don't need kilo also dont need buddha",
#   'who is trading dark blade and 1 or 2 good fruits',
#   'trading string,rumble,phoenix,quake for buddha',
#   'trading love for quake and dark or Gravity or any fruits i dont have',
#   '49M+ beli 145k frags and max lvl with cdk and v4 shark. for 30$',
#   'any gamepass under 500 + venom + spirit for leopard',
#   'always looking for perm shadow venom blizzard string rumble',
#   'trading 4 dough= 2 leopard',
#   'have 3 fruit storage',
#   'looking for really good psx pets and rumbles',
#   'bloxfruit trade psx',
#   'trading 3 doughs and a leo for perm fruits dm',
#   'trading these fruits lf good offer',
#   'anything',
#   'trade dragon and portal',
#   'trading doughs',
#   'trading gravity, string, and light for any game pass',
#   'who can buy i and do peionix raid dm me i have good offer',
#   'trading gud stuff',
#   'trading Phoenix string love and quake + adds',
#   'trading buddha portal',
#   'traed bodha and rumble',
#   'trading good fruits for pet sim x stuff',
#   'leopard trading',
#   'trading dragon spirit 2controls and buddha',
#   'trying to get control',
#   'my friend trading dough for 2x money (dm me)',
#   'looking for dough or venom',
#   'everyone post🍌',
#   'get your modding up not your funny up 🤑',
#   'trading spirit, portal, shadow, rumble, buddha and pheonix',
#   'anyone have stored?',
#   'trading 🍩',
#   ':phoenix: :quake: :tradepointer: ❓',
#   'trading dough, rumble, buddha',
#   'my portal love for control',
#   'trading shadow , blizzard , control',
#   'trading shadow gravity spider and love',
#   'trading Leo dough and dragon',
#   'trading 2 control and venom',
#   'trading portal,love,light,magma',
#   'selling leopard for 500rubox',
#   'leopard, phoenix , portal, phoenix',
#   'control- buddha- paw -spider -rumble for dragon : )',
#   'trading dragon spirit venom paw',
#   'i wan dough',
#   'trading magma and light for good offer',
#   'trading Leo for 4 dragons',
#   'trading two doughs only good offers',
#   'trading dragon for darkblade',
#   'sample 1',
#   'trading blox fruits for gpo (ngf)',
#   'anyone need help with doing the trials for v4?',
#   'trading dm me',
#   'trading control venom  portal and buddha',
#   'i got 2 spirit control venom shadow blizzard portal pheonix spider love and buddha LF dark blad',
#   'trading x2 mastery',
#   '2x money for perm light',
#   'looking for storage for dough',
#   'trading shadow rumble and buddha',
#   'search spirit or venom',
#   'trading 2x Money and 2x Mastery and other fruits for perms or gamepasses',
#   'string and extra fruit storage for dough and control',
#   'trading dough, venom, shadow, ramble',
#   'ウルフカットの男の子っぽい女の子',
#   'who can lvl my acc up to 500 i pay with perma flame andi will pay after because i have bobux and i w',
#   'you can offer for one if you want',
#   'aut',
#   'offers for perm dough?',
#   'trading leopard,venom,spirit',
#   'shadow for buddah',
#   'trading any perm under 2000rbx for any good offer',
#   'trade 1dough 1venom 1 blizzard 2 rumble 2 spider w love 2 budha 2 quake',
#   'trading leopard for stuff in pet sim',
#   'trading dough and spirit',
#   'who have buddha dm me!!',
#   'trading perm leopard',
#   'trading  spirit venom and dragon for leopard',
#   'trading shadow + portal for dough',
#   'any perm or gamepass',
#   'trading 4 leo 2 dough 1 dragon 1 control',
#   'trading rumble for Buddha',
#   'any leopards',
#   'trading Albino monkey fr for dough and spirit',
#   'dough for fast boats',
#   'trading buddha spider and love',
#   'trading blizzard and buddha',
#   'trading spiderstring',
#   'trading 1dragon 1spirit 1venom 1blizzard 1portal 1dough for darkblade',
#   'trading any game pass but fruit something and dark blade',
#   'trading blizard dragon for dough',
#   'loking for perm mgama',
#   'trading spider,magma and phoenix',
#   'trading spider and quake',
#   'trading doug and Buddha for fruit storage',
#   'trading 7 controls',
#   'tRADING BLIZZARD AND QUAKE',
#   'trading Control and Shadow',
#   'my shadow fruit for your Buddha and pheonix',
#   'have dark blade want over pay',
#   'looking for fruit storage dm me',
#   'trading pheonix and blizzard',
#   'tarding (1) leo (2dough) (1) 350gp ( dough/fastboats)',
#   'trading control and rumble',
#   'trading these for perm Leo and I’ll add blox fruit dragon venom spirit and Buddha',
#   'shadow buddha for dragon',
#   'trading paw and rumble for buddha',
#   'have leopard … looking for +2 storage',
#   'trade my fruit for leo',
#   'trading venom buddha rumble',
#   'lf 1+ storage',
#   'trading guidelines',
#   'trading dark made for dragon',
#   '⁉TRADING⁉',
#   'trading adopt me for blox fruits',
#   'looking for perm flame',
#   'trading perm kilo an offers #',
#   'trading normal buddha',
#   'trading control shadow and spider',
#   '2X MASTERY FOR VENOM AND DRAGON',
#   'i trade venom for buddha and shadow',
#   ':storage: :storage: :storage: :dragon~1: 👉:dough: :perm:',
#   'lvls',
#   'trading shadow and portal for venom',
#   'need perm fruit',
#   'trade control,poison',
#   'trading dough venom and portal',
#   'trading Leo lf dragon dough add',
#   'trading phoenix and string for rumble',
#   'trade blizzard',
#   'trading my dragon and control fruit which is rework soon',
#   'guys can some one carry magma raid i host',
#   'venom for good fruits',
#   'trying to get dragon 🐲',
#   'dough for anything good',
#   'trading 2 gravity',
#   'trading spirit 2 blizzard and buddha',
#   'trading leo for 2 +1 storages',
#   'trading perm fire for',
#   'trading3 x2 xp',
#   'can anyone summon dough king, i need mirror fractal for race 4',
#   'trading dragon, venom, shadow, paw, portal for leopard',
#   'anyone have magma unstored',
#   'trading bliz buddah and gravity looking for an upgrade trade ill add control if good offer',
#   'i have 2 porta',
#   'trading dough, venom, spirit and rumble for leopard',
#   'trading 2 buddha and rumble and 3  Love fruits',
#   'trading quake,string,paw',
#   'looking for fast boats i offer venom',
#   'i need capacitt dm me',
#   'trading shadow & buddha',
#   'lf fast boats',
#   '$10 nitro for something perm',
#   'lf PERM DOUGH',
#   'trading Phoenix for buddha',
#   'trading Buddha,Paw and spider offer',
#   '2 drag for leo',
#   'offer for venom or paw or string x2',
#   'someone plz trade me',
#   'looking for gp or good perm fruit ( not trade fruit)',
#   'anyone trading perm dough?',
#   'dough venom and Phoenix',
#   'offering for buddha',
#   'looking for good offers',
#   'trading mm2  godlys for gamepasses and perm fruits',
#   'fruit trade',
#   'trading leo offer?',
#   'get new server logo cuz i dont like thsi one',
#   'shadow +phoenix',
#   'treading blizzard for dragon or venom or spirit',
#   '2x MASTERY',
#   'venom and control',
#   'looking for perm dough or just regular leopard',
#   'tradeblizzard & portal for perm flame',
#   'trading dragon , buddha,shadow, rumble',
#   'offering magma barrier dark and fire',
#   'troco fenix pata e fio',
#   'lf Leo or offers',
#   '1 quake for 1 magma plss!!!',
#   'trading rumble and magma looking for offers',
#   'trading 3 love and 1 quake',
#   'trading rumble any offers?.',
#   'trading control for dough or dragon or venom',
#   'who NEEDS LOVE!',
#   'trading portal for 2 quakes',
#   'w or l I',
#   'trade leopard',
#   'trading buddha string paw portal',
#   'free blox fruit scripting',
#   'trading portal and string',
#   'trading gravity portal paw quake',
#   'leopard for good gamepass or dark blade',
#   'wondering what i can get with these',
#   'giving huge pets who can carry raids and help trial and training =))',
#   'trading portal for rumble',
#   'ok test',
#   'looking for x2 boss drops',
#   'offers dm',
#   'post',
#   "trading ps access for 2 buddah's",
#   'trading shadoww LF budda adds',
#   'trading quake, buddha, phoenix, control, spirit',
#   'trading Leo, Dough, Venom, and Dragon LOOKING FOR PERMS ONLYY',
#   'can someone plz give me bough plz',
#   'trading string and quake for portal',
#   'gifting perm fruits for offer',
#   'if u want',
#   'looking for plus 1 storage',
#   'trading 300 black men for 2 pounds',
#   'trading leo for dragon and add.',
#   'trading blizz rumble pheonix love',
#   'i need dough',
#   'two dough for Leo',
#   'trading blizzard and quake for spirit',
#   'regalen Phoenix/gift me Phoenix',
#   'does anyone have anything good for phoenix spider or love dm me if you have good offer',
#   'perm or something good',
#   'trading perm leo',
#   'trading perm magu for leopard',
#   'trading 3 dragon and 1 dough',
#   'trading dough grav x2 Phoenix and Buddha',
#   'trading perm magma LF 2 leos and 2 doughs',
#   'trading leo 2x venom 2x controll and dough',
#   '2 LEO 1 DOUGH 1 SPIRIT 2 PAW 1 BUDDHA',
#   'lf perm magma or perm spirit',
#   'trading plus one fruit storage',
#   'trading venom,phofenix,buddah',
#   'trading spirit, venom, shadow, portal',
#   '<:perm:1052883456226500688> <:buddha:997791357852721212> <:tradepointer:1008289176086650951> <:leopa',
#   'trading spirit for venom and buddha',
#   'trying to trade love',
#   '🌋♾👉❔',
#   'lf indra',
#   'portal for human',
#   'trials',
#   'hosting and carrying dough raid',
#   'anyone got dough for these?',
#   'giving dark blade to whoever can help me get human v4 and mirror fragment',
#   'spirit for',
#   'leo and quake for 2 storages',
#   'dragon 2spirit blizzard and buddha',
#   'trading spirit and string',
#   'hosting and carrying dough raids for a quake to start',
#   'trading venom shadow budha and perm spin',
#   'blizzard and dragon',
#   'trading spirit venom Buddha for dragon',
#   'trading this Fruits',
#   'trasing dragon spirit and paw dm with offers',
#   'trading quake or portal for magma',
#   'trading bouddha and blizzard',
#   'dough and portal for storage',
#   'have spirit want rumble and prob an add',
#   'test to forum announcements',
#   'offering gravity for sumthing better',
#   'trading blizzard, light, and magma.',
#   'trying to get rumble',
#   'got shadow, gravity, blizzard',
#   '6 leopards for fruit Notifier',
#   'trading anything 1700 rublox or under',
#   'looking for spirit offer(venom budda ) add portal maybe',
#   'trading door string and quake',
#   'trading dough for dark blade',
#   'trading control and phoenix fr fr',
#   'trading fast boats or 2x drop rates',
#   'trading rumble quake and magma',
#   'trading 2x money',
#   'trading rubber',
#   'trading for leopard/tradeando por leopardo',
#   'list of how many mods per role',
#   'leopard, shadow, and phoenix for 2 dough, 1 dragon, and 1 buddha',
#   'aqui tem dragon e Control',
#   '2 leos plus adds for Perm Portal',
#   'trading leopard and spirit for gamepass and dough',
#   'looking for dark blade dm me if you got',
#   'trading 2dragons and 2 buddhas',
#   '*TRADING VENOM  DM ME*',
#   'what is the best v4',
#   'alan smells',
#   '🌲 — tree',
#   'looking for perm portal or buddha',
#   'i have 4 buddha offer ?',
#   'trading these make your offers',
#   'trading grav and portal',
#   "possum's pavilion",
#   'trading shadow,rumble,paw and spider for dough',
#   'trading gravity for pheonix, rumble or blizzard',
#   'dough and portal for perm string',
#   'trading from kilo up to a leo,i now have obtained dough',
#   'trading gravity and magma for buddha',
#   'loking for buddha and portak',
#   'lf rubber',
#   'trading dough,venom,and blizzard',
#   'trading 2 dough and shadow and venom for fruit notfite',
#   'trading buddah for 12 hour 2x exp',
#   'trading paw phoniex love and quake for a good offer (you can offer for one of them)',
#   'trading 4 leos',
#   'trading perm fruit',
#   'want dark blade will trade venom for dark blade',
#   'trading 2dragon and spirit and control for prem Portal',
#   'looking for a good offer I have',
#   'trade 1 dough 1 venom 1 blizzard 2 rumble 2 spider 2 love and 1 budha',
#   'trading dragon rumble pheonix 2 string',
#   'trading buddha and portal for dough',
#   'can anyone give me a good fruit pls',
#   'only lf for perms',
#   'trading dough control shadow blizzard for fruit storage',
#   'will give love for dough king',
#   'trading venom for 2 Buddha and paw or control + add',
#   'i tread shadow phoenix light',
#   'trading Venom',
#   'trading 1 slot',
#   'trading blizzard for dragon and buddha',
#   'idkdkdkej',
#   'leopard buddha shadow phoenix portal',
#   '2 spirits 1 venom 1 shadow and rumble for leopard',
#   ':Venom: :Buddha: :Control: :Spirit: :Point_Trade: :Ofertas:',
#   'looking for control, my offer is portal and string',
#   'trading any gp you want just dm me',
#   'mid tiers for quake',
#   'offer for control',
#   'looking for paw gravity',
#   'lf perm love',
#   'trading for a perm magma',
#   'trading leo, control, shadow, dough, dragon, gravity, blizzard, phoenix, and quake',
#   'trading pet sim x/ adopt me/$$ for blox fruits',
#   'trading Dragon leopard control',
#   'trading 1 love and 1 quake for portal',
#   'trading rumble love and two strings or one for good offers',
#   'i tread blizzard spirit',
#   'lf venom i got grav portal phoenix and magma',
#   'trading 2 spirits',
#   'trading dragon and spirit',
#   'trading dough for 2 buddha and good add',
#   'play chess with me pls',
#   'y',
#   'trading leo (adleast 1 dough and dragon +adds)',
#   'trading Leo for good offers',
#   'trading shadow dough and dragon',
#   'trading 2 dragon for leopard',
#   'control and 2 shadows for 2x mastery game pass',
#   'trading a paw fruit',
#   'trading shadow paw n phoenix',
#   'trading leopard dough two venoms buddha two quakes and love offer up',
#   'trading portal for quake and rubber and love',
#   'trading leopard for +1 fruit dough spirt and venom',
#   'trading dough for you to download app or giving acc with dark blade 2xp and 2xmoney will give proof',
#   'trading Leo and venom',
#   'trading spirit, buddha, and dough for perm magma',
#   'trade...',
#   'trding for good offer',
#   'trading blizzard and phenoix for good offer',
#   'what perm buddha have dough, rumble, and phoenix',
#   'i wanr buddha for my fruits',
#   'trading Leopard for Gamepass',
#   'trading venom spirit and blizzard',
#   'trading control and love',
#   'trading buddha and perm kilo',
#   'trade dragon,spirit,portal',
#   'leopard control and spider',
#   'trading good fruits (mythical) for pet sim x pets and gems',
#   'dragon for dough venom and buddha',
#   'trading for dough i have venom spirit',
#   'trading control, dough and buddha',
#   'trading Leopard control and dragon for a perm',
#   'looking for Buddha dm me',
#   'my blizzard for spirit',
#   'trading buddha for portal+adds',
#   'trading Dragon and Spirit',
#   'looking for phoenix and buddha, i offer shadow',
#   'trading venom and love',
#   'trade game pass',
#   'trade blizard',
#   'gravity phoenix and quake trade',
#   'dragon and portal for dough 💀💀',
#   'trading dragon and control for dough',
#   'spirit and paw for 2x money',
#   'thuat thread',
#   'looking for shadows buddhas and doughs',
#   'trading shadow love magma for venom',
#   'trading spirit to rumble and buddha',
#   'trading dough gravity  spirit spider paw and phoenix',
#   'string quake 👉❓',
#   'tradind dough',
#   'trading phoenix quake revive diamond for More no downgrades.',
#   'chqma',
#   'trading Buddha and control and phoniex',
#   ...}}

# %% [markdown]
# ### Spam Documents for Content

# %%
import pandas as pd

def spam_document_detection(dataframe, min_content_length=10):
    # Check if the 'content' column is present in the DataFrame
    if 'content' not in dataframe.columns:
        return "The 'content' column does not exist in the DataFrame."

    spam_count = 0
    valid_count = 0
    spam_documents = []

    for content in dataframe['content']:
        if isinstance(content, str):
            # Check if content is too short or nonsensical
            if len(content) < min_content_length:
                spam_count += 1
                spam_documents.append(content)
            else:
                valid_count += 1
        else:
            spam_count += 1  # Treat non-string content as spam

    total_documents = len(dataframe)

    return {
        "Total Documents": total_documents,
        "Valid Documents Count": valid_count,
        "Spam Documents Count": spam_count,
        #"Spam Documents": set(spam_documents)
    }

# Example usage:
# Assuming you have a DataFrame called 'my_data' and a minimum content length of 50 characters
result = spam_document_detection(df, min_content_length=10)
print(result)
# Out:
# {'Total Documents': 1967974, 'Valid Documents Count': 1309995, 'Spam Documents Count': 657979}

# %% [markdown]
# ### Spam Documents for Title

# %%
import pandas as pd

def title_content_validation(dataframe, min_tokens=3):
    # Ensure that "title" and "content" fields are strings and not empty or null
    if dataframe['title'].isnull().any() or not dataframe['title'].astype(str).str.strip().all():
        print("Error: Some 'title' values are missing or empty.")
        # return None

    if dataframe['content'].isnull().any() or not dataframe['content'].astype(str).str.strip().all():
        print("Error: Some 'content' values are missing or empty.")
        # return None

    # Check the distribution of the number of tokens for title and content
    title_tokens_count = dataframe['title'].str.split().str.len()
    content_tokens_count = dataframe['content'].str.split().str.len()

    # Check the number of documents with title and/or content less than X tokens
    if (title_tokens_count < min_tokens).any():
        print("Warning: Some documents have 'title' with fewer than {} tokens.".format(min_tokens))
        print("Value Counts:\n{}".format(title_tokens_count[title_tokens_count < min_tokens].value_counts()))

    if (content_tokens_count < min_tokens).any():
        print("Warning: Some documents have 'content' with fewer than {} tokens.".format(min_tokens))
        print("Value Counts:\n{}".format(content_tokens_count[content_tokens_count < min_tokens].value_counts()))

    # Replace NaN values with an appropriate placeholder
    dataframe['title']=dataframe['title'][~dataframe.title.isnull()]
    dataframe['content']=dataframe['content'][~dataframe.content.isnull()]

    # Filter out rows with NaN or null values in 'title' and 'content' columns
    dataframe1 = dataframe.dropna(subset=['title', 'content'])

    # Check documents that only have numbers or special characters in the content and/or title
    has_numbers_title = dataframe1['title'][dataframe1['title'].str.isnumeric()].count()
    has_numbers_content = dataframe1['content'][dataframe1['content'].str.isnumeric()].count()
    has_special_chars_title = dataframe1['title'][(dataframe1['title'].str.match(r'^[^a-zA-Z0-9]+$'))].count()
    has_special_chars_content = dataframe1['content'][(dataframe1['content'].str.match(r'^[^a-zA-Z0-9]+$'))].count()


    if has_numbers_title > 0 or has_numbers_content > 0:
        print(f"Warning: Some documents have numbers in the 'title' count: {has_numbers_title} or 'content' count: {has_numbers_content}.")
    else:
        print('Content and Title have no numbers.')

    if has_special_chars_title > 0 or has_special_chars_content > 0:
        print(f"Warning: Some documents have special characters in the 'title' count: {has_special_chars_title} or 'content' count: {has_special_chars_content}.")
    else:
        print('Content and title have no special characters.')
    
    return {
        "Title Missing or Empty": dataframe['title'].isnull().sum(),
        "Content Missing or Empty": dataframe['content'].isnull().sum(),
        "Title Less Than {} Tokens".format(min_tokens): (title_tokens_count < min_tokens).sum(),
        "Content Less Than {} Tokens".format(min_tokens): (content_tokens_count < min_tokens).sum(),
        "Title Has Only Numbers": has_numbers_title,
        "Content Has Only Numbers": has_numbers_content,
        "Title Has Only Special Characters": has_special_chars_title,
        "Content Has Only Special Characters": has_special_chars_content
    }

# Example usage:
# Assuming you have a DataFrame called 'my_data' and a minimum token count of 3
result = title_content_validation(df, min_tokens=3)
print(result)
# Out:
# Error: Some 'title' values are missing or empty.
# Error: Some 'content' values are missing or empty.
# Warning: Some documents have 'title' with fewer than 3 tokens.
# Value Counts:
# title
# 1.0    14148
# 2.0    11793
# Name: count, dtype: int64
# Warning: Some documents have 'content' with fewer than 3 tokens.
# Value Counts:
# content
# 1.0    555182
# 2.0    255502
# Name: count, dtype: int64
# Warning: Some documents have numbers in the 'title' count: 5 or 'content' count: 108.
# Warning: Some documents have special characters in the 'title' count: 158 or 'content' count: 992.
# {'Title Missing or Empty': 1885504, 'Content Missing or Empty': 20602, 'Title Less Than 3 Tokens': 25941, 'Content Less Than 3 Tokens': 810684, 'Title Has Only Numbers': 5, 'Content Has Only Numbers': 108, 'Title Has Only Special Characters': 158, 'Content Has Only Special Characters': 992}

# %%
df.title[~df.title.isnull()]
# Out:
# 8                                                       hehe
# 12                                          trading blizzard
# 23                          Trading 2 loves for portal fruit
# 27                                  Case Circus Tent Factory
# 37                                                      hehe
#                                  ...
# 1967915                            Basement’s Delta Bootcamp
# 1967943                                                 hehe
# 1967952                                                 hehe
# 1967967    Trading gravity, quake phoenix and rumble for ...
# 1967968                                          trading Leo
# Name: title, Length: 82470, dtype: object

# %%
def plot_top_token_lengths(df):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))  # Create a subplot with 2 rows and 2 columns

    # Loop through the columns 'content' and 'title'
    for idx, column_name in enumerate(['content', 'title']):
        # Split the column into tokens, count token lengths, and get value counts
        tokens = df[column_name].str.split().str.len().value_counts().reset_index()
        tokens_10 = tokens.head(10).sort_values(by='count', ascending=False)  # Sort in descending order

        # Create the bar plot in the corresponding subplot
        sns.barplot(data=tokens_10, x=column_name, y='count', palette='rocket', ax=axes[0, idx])
        axes[0, idx].set_xlabel(f'{column_name.capitalize()} Token Length')
        axes[0, idx].set_ylabel('Count')
        axes[0, idx].set_title(f'Top 10 {column_name.capitalize()} Token Lengths')

        # Calculate character lengths for the same column and get their value counts
        char_lengths = df[column_name].str.len().value_counts().reset_index()
        char_lengths_10 = char_lengths.head(10).sort_values(by='count', ascending=False)  # Sort in descending order

        # Create the bar plot for character lengths in the second row
        sns.barplot(data=char_lengths_10, x=column_name, y='count', palette='rocket', ax=axes[1, idx])
        axes[1, idx].set_xlabel(f'{column_name.capitalize()} Character Length')
        axes[1, idx].set_ylabel('Count')
        axes[1, idx].set_title(f'Top 10 {column_name.capitalize()} Character Lengths')

    plt.tight_layout()  # Ensure proper spacing between subplots
    plt.show()

plot_top_token_lengths(df)

# %% [markdown]
# #### In The content Column The highest Distribution of Token is 1
# - In which top 10 value count are below

# %%
content_hig_token=df.content[df.content.str.split().str.len()==1].value_counts().reset_index()

# %%
content_hig_token.head(10)
# Out:
#         content  count
# 0           $wa  10866
# 1         .bake  10174
# 2      .harvest   9855
# 3           bal   9767
# 4  .stealcookie   9086
# 5            $h   6220
# 6             a   5131
# 7            $w   5084
# 8            Ok   4963
# 9             ?   4360

# %% [markdown]
# #### Average character length for content

# %%
content_hig_token.content.str.len().mean()
# Out:
# 21.60699526796994

# %% [markdown]
# **Content Character highest frequancy analysis**

# %%
df.content[df.content.str.len()==3].value_counts()
# Out:
# content
# $wa    10866
# bal     9767
# Bal     3930
# Lol     3876
# Yes     3094
#        ...
# eep        1
# +pl        1
# sax        1
# 😍🥰😘        1
# S$h        1
# Name: count, Length: 7337, dtype: int64

# %%
df.content[df.content.str.len()==3].value_counts().head(10)
# Out:
# content
# $wa    10866
# bal     9767
# Bal     3930
# Lol     3876
# Yes     3094
# lol     2288
# Nty     2124
# yes     2072
# nty     1603
# $ma     1450
# Name: count, dtype: int64

# %% [markdown]
# #### Title column Analysis

# %%
Token_token_1=df.title[df.title.str.split().str.len()==1].value_counts().reset_index()

# %%
Token_token_1
# Out:
#                   title  count
# 0                  hehe   5397
# 1                 BBois   3225
# 2               trading    903
# 3               Trading    406
# 4                 trade    279
# ..                  ...    ...
# 653                 aaa      1
# 654            Trading🤩      1
# 655           Chemistry      1
# 656  Ciosciaa-1/27/2023      1
# 657         backupStaff      1
#
# [658 rows x 2 columns]

# %% [markdown]
# #### In The Title Column The highest Distribution of Token is 3
# - In which top 10 value count are below

# %%
Title_hig_token=df.title[df.title.str.split().str.len()==3].value_counts().reset_index()

# %%
Title_hig_token.head(10)
# Out:
#                             title  count
# 0                 Theta Wins Only   3347
# 1           Theta Galactic Empire   2533
# 2            Kolo’s Future Korner    309
# 3         Balthius' Better Bazaar    291
# 4                  trading my inv    163
# 5  Nick_OS—$500 account challenge    156
# 6                BIG TRADE ALERT!    145
# 7             trading perm Buddha    141
# 8       Basement’s Delta Bootcamp    140
# 9          MidJourney Bot Testing    139

# %% [markdown]
# #### Average character length for Title

# %%
Title_hig_token.title.str.len().mean()
# Out:
# 17.07318022576878

# %% [markdown]
# #### Character highest frequancy analysis 4 and 15

# %%
df.title[df.title.str.len()==4].value_counts().reset_index()
# Out:
#    title  count
# 0   hehe   5397
# 1   FD's    125
# 2   news     50
# 3   tree     43
# 4   post     37
# ..   ...    ...
# 70  🌋♾👉❔      1
# 71  2Leo      1
# 72  Winn      1
# 73  suii      1
# 74  HELO      1
#
# [75 rows x 2 columns]

# %%
df.title[df.title.str.len()==15].value_counts().reset_index()
# Out:
#                title  count
# 0    Theta Wins Only   3347
# 1    trading control    263
# 2    trading leopard    239
# 3    Rumy struggling    129
# 4    Trading Leopard     95
# ..               ...    ...
# 441  Who have budha?      1
# 442  Offer for venom      1
# 443  Daily fact #132      1
# 444  venom for dough      1
# 445  LF GREAT OFFERS      1
#
# [446 rows x 2 columns]
